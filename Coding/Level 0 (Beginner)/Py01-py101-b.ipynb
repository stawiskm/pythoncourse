# %% [markdown]
# # Programming with Python
# ## Table of Contents
# - [Variables](#variables)
# - [Data Types](#data-types)
#   - [Numeric Types](#numeric-types)
#   - [Strings](#strings)
#   - [Booleans](#booleans)
# - [Lists, Sets, and Dictionaries](#lists-sets-and-dictionaries)
#   - [Lists](#lists)
#   - [Sets](#sets)
#   - [Dictionaries](#dictionaries)
# - [Operators](#operators)
#   - [Arithmetic Operations](#arithmetic-operations)
#   - [Comparison Operators](#comparison-operators)
#   - [Logical Operators](#logical-operators)
#   - [Assignment Operators](#assignment-operators)
#   - [Identity Operators](#identity-operators)
#   - [Membership Operators](#membership-operators)
# - [Conditions and Conditional Statements](#conditions-and-conditional-statements)
#   - [If Statements](#if-statements)
# - [Loops: while and for, continue, break](#loops-while-and-for-continue-break)
#   - [while Loop](#while-loop)
#   - [for Loop](#for-loop)
#   - [continue and break Statements](#continue-and-break-statements)
# - [Functions](#functions)
#   - [Defining Functions](#defining-functions)
# - [External Libraries](#external-libraries)
#   - [Installing External Libraries](#installing-external-libraries)
#   - [Importing External Libraries](#importing-external-libraries)
#   - [Popular Libraries](#popular-libraries)
# - [Basics of Terminal Commands](#basics-of-terminal-commands)
#   - [Running Python Files](#running-python-files)
#   - [Navigating Directories](#navigating-directories)
#   - [Listing Files and Directories](#listing-files-and-directories)
#   - [Creating and Deleting Files/Directories](#creating-and-deleting-filesdirectories)
# - [Conclusion](#conclusion)

# %% [markdown]
# # Variables
# Variables are used to store information that can be referenced and manipulated in a program. In Python, you can create a variable by simply assigning a value to it using the `=` operator.
#
# ### Example:
# ```python
# x = 10
# name = "Alice"
# ```
#
# ### TODO:
# - Create a variable `age` and set it to your age.
# - Create a variable `city` and set it to the name of your city.

# %%
# TODO: Assign your age to the variable 'age'
age = 

# TODO: Assign the name of your city to the variable 'city'
city =

# %% [markdown]
# # Data Types
# Python has various data types including numeric types, strings, and booleans.
#
# ## Numeric Types
# Numeric types include integers (`int`) and floating-point numbers (`float`).
#
# ### Example:
# ```python
# a = 5        # int
# b = 3.14     # float
# ```
#
# ### TODO:
# - Create an integer variable `num1` with the value 42.
# - Create a float variable `num2` with the value 3.14.

# %%
# TODO: Assign an integer value to 'num1'
num1 = 

# TODO: Assign a float value to 'num2'
num2 =

# %% [markdown]
# ## Strings
# Strings are sequences of characters enclosed in quotes.
#
# ### Example:
# ```python
# greeting = "Hello, world!"
# ```
#
# ### TODO:
# - Create a string variable `welcome_message` with the value "Welcome to Python!".

# %%
# TODO: Assign a string value to 'welcome_message'
welcome_message =

# %% [markdown]
# ## Booleans
# Booleans represent one of two values: `True` or `False`.
#
# ### Example:
# ```python
# is_sunny = True
# is_raining = False
# ```
#
# ### TODO:
# - Create a boolean variable `is_student` and set it to `True` if you are a student.

# %%
# TODO: Assign a boolean value to 'is_student'
is_student =

# %% [markdown]
# # Lists, Sets, and Dictionaries
# ## Lists
# Lists are ordered collections of items, which can be of any type.
#
# ### Example:
# ```python
# fruits = ["apple", "banana", "cherry"]
# ```
#
# ### TODO:
# - Create a list `colors` containing at least three colors.
# - Remove the last item from the `colors` list.
# - Add a new color to the end of the `colors` list.

# %%
# TODO: Assign a list of colors to 'colors'
colors = 

# TODO: Remove the last item from the list
colors

# TODO: Add a new color to the list
colors

# %% [markdown]
# ## Sets
# Sets are unordered collections of unique items.
#
# ### Example:
# ```python
# unique_numbers = {1, 2, 3, 4, 5}
# ```
#
# ### TODO:
# - Create a set `unique_letters` containing the letters 'a', 'b', and 'c'.
# - Add the letter 'd' to the `unique_letters` set.
# - Add the letter 'a' to the `unique_letters` set.
# - Remove the letter 'b' from the `unique_letters` set.
# - Remove the letter 'z' from the `unique_letters` set.
# - Remove the letter 'a' from the `unique_letters` set.
# - Print the length of the `unique_letters` set.

# %%
# TODO: Assign a set of unique letters to 'unique_letters'
unique_letters = 

# TODO: Add the letter 'd' to the set

# TODO: Add the letter 'a' to the `unique_letters` set.

# TODO: Remove the letter 'b' from the `unique_letters` set.

# TODO: Remove the letter 'z' from the `unique_letters` set.

# TODO: Remove the letter 'a' from the `unique_letters` set.

# TODO: Print the length of the `unique_letters` set.

# %% [markdown]
# ## Dictionaries
# Dictionaries are collections of key-value pairs.
#
# ### Example:
# ```python
# person = {"name": "Alice", "age": 25}
# ```
#
# ### TODO:
# - Create a dictionary `student` with keys `"name"`, `"age"`, and `"grade"`, and assign appropriate values to them.
# - Add a new key-value pair to the `student` dictionary.
# - Remove the `"grade"` key from the `student` dictionary.
# - Print the value associated with the `"name"` key in the `student` dictionary.
# - Print the keys of the `student` dictionary.

# %%
# TODO: Assign a dictionary with keys 'name', 'age', and 'grade' to 'student'
student = 

# TODO: Add a new key-value pair to the `student` dictionary.

# TODO: Remove the `"grade"` key from the `student` dictionary.

# TODO: Print the value associated with the `"name"` key in the `student` dictionary.

# TODO: Print the keys of the `student` dictionary.

# %% [markdown]
# # Operators
# Operators are used to perform operations on variables and values.
#
# ## Arithmetic Operations
# These include `+`, `-`, `*`, `/`, and `%`.
#
# ### Example:
# ```python
# sum_result = 5 + 3
# ```
#
# ### TODO:
# - Create a variable `product` and set it to the result of multiplying `num1` by `num2`.

# %%
# TODO: Calculate the product of 'num1' and 'num2'
product =

# %% [markdown]
# ## Comparison Operators
# These include `==`, `!=`, `>`, `<`, `>=`, and `<=`.
#
# ### Example:
# ```python
# is_equal = (5 == 5)
# ```
#
# ### TODO:
# - Create a boolean variable `is_greater` that checks if `num1` is greater than `num2`.

# %%
# TODO: Compare 'num1' and 'num2' using a comparison operator
is_greater =

# %% [markdown]
# ## Logical Operators
# These include `and`, `or`, and `not`.
#
# ### Example:
# ```python
# is_adult = (age > 18) and (age < 65)
# ```
#
# ### TODO:
# - Create a boolean variable `can_vote` that is `True` if `age` is greater than or equal to 18 and `False` otherwise.

# %%
# TODO: Use logical operators to determine if the person can vote
can_vote =

# %% [markdown]
# ## Assignment Operators
# These include `=`, `+=`, `-=`, `*=`, `/=`, etc.
#
# ### Example:
# ```python
# counter = 0
# counter += 1  # Increment counter by 1
# ```
#
# ### TODO:
# - Create a variable `score` and set it to 0. Then, increment `score` by 10.

# %%
# TODO: Assign a value to 'score' and increment it by 10
score = 0
score +=

# %% [markdown]
# ## Identity Operators
# These include `is` and `is not` to check if two variables point to the same object.
#
# ### Example:
# ```python
# a = [1, 2, 3]
# b = a
# is_same = (a is b)
# ```
#
# ### TODO:
# - Create two variables `list1` and `list2`, both assigned to the same list. Check if they are the same using `is`.

# %%
# TODO: Assign the same list to 'list1' and 'list2', then check if they are the same
list1 = 
list2 = 
is_same =

# %% [markdown]
# ## Membership Operators
# These include `in` and `not in` to check membership in sequences.
#
# ### Example:
# ```python
# numbers = [1, 2, 3, 4]
# is_in_list = (3 in numbers)
# ```
#
# ### TODO:
# - Check if the color 'blue' is in the `colors` list.

# %%
# TODO: Check if 'blue' is in the list 'colors'
is_blue_in_colors =

# %% [markdown]
# # Conditions and Conditional Statements
# ## If Statements
# Conditional statements allow us to execute code based on certain conditions.
#
# ### Example:
# ```python
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
# ```
#
# ### TODO:
# - Write an if statement that prints `"Eligible to vote"` if `age` is 18 or older, and `"Not eligible to vote"` otherwise.

# %%
# TODO: Write an if statement to check voting eligibility
if age >= 18:
    
else:

# %% [markdown]
# # Loops: while and for, continue, break
# ## while Loop
# A `while` loop continues to execute as long as a condition is true.
#
# ### Example:
# ```python
# count = 0
# while count < 5:
#     print(count)
#     count += 1
# ```
#
# ### TODO:
# - Write a while loop that prints the numbers from 1 to 10.

# %%
# TODO: Write a while loop to print numbers from 1 to 10
count = 1
while count <= 10:

# %% [markdown]
# ## for Loop
# A `for` loop is used to iterate over a sequence (like a list, tuple, or string).
#
# ### Example:
# ```python
# for fruit in fruits:
#     print(fruit)
# ```
#
# ### TODO:
# - Write a for loop that iterates over the `colors` list and prints each color.

# %%
# TODO: Write a for loop to print each color in the list 'colors'
for color in colors:

# %% [markdown]
# ## continue and break Statements
# `continue` skips the current iteration of the loop, while `break` exits the loop entirely.
#
# ### Example:
# ```python
# for i in range(10):
#     if i == 5:
#         continue
#     print(i)
# ```
#
# ### TODO:
# - Write a loop that prints numbers from 1 to 10, but skips the number 5 using `continue`.

# %%
# TODO: Write a loop to print numbers from 1 to 10, skipping 5
for i in range(1, 11):
    if i == 5:
        continue
    print(i)

# %% [markdown]
# # Functions
# ## Defining Functions
# Functions are blocks of code that only run when they are called.
#
# ### Example:
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# ```
#
# ### TODO:
# - Write a function `square` that takes a number as an argument and returns its square.

# %%
# TODO: Define a function 'square' that returns the square of a number
def square(number):

# %% [markdown]
# # External Libraries
# ## Installing External Libraries
# External libraries can be installed using `pip`, Python's package installer.
#
# ### Example:
# ```bash
# !pip install numpy
# ```
#
# ### TODO:
# - Install the `requests` library using pip.

# %%
# TODO: Install the 'requests' library using pip
# !pip install requests

# %% [markdown]
# ## Importing External Libraries
# Once installed, libraries can be imported using the `import` statement.
#
# ### Example:
# ```python
# import numpy as np
# ```
#
# ### TODO:
# - Import the `requests` library.

# %%
# TODO: Import the 'requests' library
import requests

# %% [markdown]
# ## Popular Libraries
# Some popular Python libraries include:
# - `numpy` for numerical computations
# - `pandas` for data manipulation
# - `matplotlib` for plotting
#
# ### TODO:
# - Explore a new library and write code to demonstrate one of its features.

# %%
# TODO: Explore a library and demonstrate a feature
# Example: Using 'matplotlib' to plot a graph
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Basics of Terminal Commands
# ## Running Python Files
# Python files can be run from the terminal using the `python` command.
#
# ### Example:
# ```bash
# python script.py
# ```
#
# ### TODO:
# - Write a Python script `hello.py` that prints "Hello, World!" and run it from the terminal.

# %% [markdown]
# ## Navigating Directories
# You can navigate directories in the terminal using the `cd` command.
#
# ### Example:
# ```bash
# cd Documents
# ```
#
# ### TODO:
# - Change to your home directory using the `cd` command.

# %% [markdown]
# ## Listing Files and Directories
# You can list files and directories using the `ls` (Linux/Mac) or `dir` (Windows) command.
#
# ### Example:
# ```bash
# ls
# ```
#
# ### TODO:
# - List the contents of the current directory.

# %% [markdown]
# ## Creating and Deleting Files/Directories
# You can create directories using `mkdir` and delete files using `rm` (Linux/Mac) or `del` (Windows).
#
# ### Example:
# ```bash
# mkdir new_folder
# rm file.txt
# ```
#
# ### TODO:
# - Create a new directory called `test_dir` and then delete it.

# %% [markdown]
# # Conclusion
# You've now covered the basics of programming with Python. Continue practicing and exploring to become proficient. Happy coding!
