# %% [markdown]
# # Guide to Plotting with Seaborn and Matplotlib in Python
#
# Welcome to the guide on plotting with Seaborn and Matplotlib! In this notebook, you'll learn how to create and customize plots using these powerful libraries.
#
# ## Table of Contents
# 1. [Introduction](#introduction)
# 2. [Installing the Libraries](#installing-the-libraries)
# 3. [Importing the Libraries](#importing-the-libraries)
# 4. [Basic Plotting with Matplotlib](#basic-plotting-with-matplotlib)
#    - [Customizing Plots](#customizing-plots)
# 5. [Basic Plotting with Seaborn](#basic-plotting-with-seaborn)
#    - [Customizing Seaborn Plots](#customizing-seaborn-plots)
# 6. [Common Plot Types](#common-plot-types)
#    - [Bar Plot](#bar-plot)
#    - [Histogram](#histogram)
#    - [Scatter Plot](#scatter-plot)
#    - [Box Plot](#box-plot)
#    - [Heatmap](#heatmap)
# 7. [Advanced Customization](#advanced-customization)
# 8. [Saving Plots](#saving-plots)
# 9. [Conclusion](#conclusion)
#
# Let's get started!

# %% [markdown]
# ## Introduction
#
# In this notebook, we'll explore how to use Seaborn and Matplotlib for data visualization in Python. Both libraries are widely used for creating a variety of plots and customizing them to meet your needs.
#
# ## Installing the Libraries
#
# First, you need to ensure that you have both Seaborn and Matplotlib installed. You can install them using pip if they are not already installed.

# %%
# Uncomment and run the following line to install the libraries if needed:
# !pip install seaborn matplotlib

# %% [markdown]
# ## Importing the Libraries
#
# Let's import the necessary libraries and check their versions to ensure everything is set up correctly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Check versions to confirm installation
print("Seaborn version:", sns.__version__)
print("Matplotlib version:", plt.matplotlib.__version__)
# Out:
# Seaborn version: 0.12.2
# Matplotlib version: 3.7.2

# %% [markdown]
# ## Basic Plotting with Matplotlib
#
# Matplotlib is a powerful library for creating static, animated, and interactive visualizations in Python. Let's start with some basic plotting.
#
# ### TODO: Create a simple line plot
# Create a basic line plot using Matplotlib. Plot the following data points:
# - x: [1, 2, 3, 4, 5]
# - y: [2, 3, 5, 7, 11]

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o')
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Customizing Plots
#
# You can customize your plots by adding titles, labels, and changing colors and markers.
#
# TODO:
# Modify the plot from the previous step to include a legend and change the line color to red.

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, color='red', marker='o', label='Prime Numbers')
plt.title('Customized Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Basic Plotting with Seaborn
#
# Seaborn provides a high-level interface for drawing attractive and informative statistical graphics. Let's create a basic plot with Seaborn.
#
# ### TODO: Create a simple scatter plot
# Using the built-in 'iris' dataset, create a scatter plot of sepal length versus sepal width.

# %%
df = sns.load_dataset('iris')

sns.scatterplot(x='sepal_length', y='sepal_width', data=df)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# ### Customizing Seaborn Plots
#
# You can customize Seaborn plots with additional parameters and themes.
#
# TODO:
# Modify the scatter plot to use the 'darkgrid' theme and change the color of the points to blue.

# %%
sns.set(style='darkgrid')

sns.scatterplot(x='sepal_length', y='sepal_width', data=df, color='blue')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# ## Common Plot Types
#
# Let's explore some common plot types that you can create using both Matplotlib and Seaborn.
#
# ### Bar Plot
#
# TODO:
# Create a bar plot showing the average petal length for each species in the iris dataset.

# %%
sns.barplot(x='species', y='petal_length', data=df, estimator='mean')
plt.title('Average Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Average Petal Length')
plt.show()

# %% [markdown]
# ### Histogram
#
# TODO:
# Create a histogram of sepal lengths from the iris dataset.

# %%
plt.hist(df['sepal_length'], bins=15, color='green', edgecolor='black')
plt.title('Histogram of Sepal Lengths')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Scatter Plot
#
# You have already created a scatter plot earlier, but here you can create another one with different data or additional customization.
#
# ### Box Plot
#
# TODO:
# Create a box plot to visualize the distribution of petal lengths across different species.

# %%
sns.boxplot(x='species', y='petal_length', data=df)
plt.title('Box Plot of Petal Lengths by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %% [markdown]
# ### Heatmap
#
# TODO:
# Create a heatmap of the correlation matrix of the iris dataset.

# %%
import pandas as pd
dummy = pd.get_dummies(df)
correlation_matrix = dummy.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Advanced Customization
#
# Explore more advanced customization techniques to fine-tune your plots.
#
# TODO:
# Experiment with customizing the plot titles, labels, colors, and styles to create a visually appealing plot. For example, you can use different color palettes or add annotations.

# %%
# TODO: Customize your plot further
# Experiment with different options and styles.

# %% [markdown]
# ## Saving Plots
#
# You can save your plots to files in various formats, such as PNG, PDF, and SVG.
#
# TODO:
# Save one of the plots you created earlier to a file.

# %%
# TODO: Save your plot to a file
# plt.savefig('plot.png', format='png')

# %% [markdown]
# ## Conclusion
#
# In this notebook, you've learned the basics of plotting with Seaborn and Matplotlib, customized your plots, explored different types of plots, and saved your visualizations. Continue practicing and experimenting with different datasets to improve your data visualization skills. Happy plotting!
